# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd
import numpy as np

import logging

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

import mlflow
import mlflow.sklearn
from itertools import combinations

# Spotify API 인증 정보
CLIENT_ID = '9c98fec7710b40d4a5822cc356bf77c7'  # 당신의 Client ID
CLIENT_SECRET = '77f933bc3213455ea9b1672f94b34fe8'  # 당신의 Client Secret
REDIRECT_URI = 'http://localhost:3000/callback'  # 리다이렉트 URI

def get_auth() -> SpotifyOAuth :
    # SpotifyOAuth에 직접 전달
    return spotipy.Spotify(
        auth_manager=SpotifyOAuth(
        client_id=CLIENT_ID,
        client_secret=CLIENT_SECRET,
        redirect_uri=REDIRECT_URI,
        scope=["user-library-read",
            "playlist-read-private",
            "playlist-modify-public",
            "user-top-read"])
            )

def get_user_playlists(sp):
    playlists = sp.current_user_playlists()
    playlist_id_list = []

    for playlist in playlists['items']:
        playlist_id_list.append(playlist['id'])
        
    return playlist_id_list

sp = get_auth()


def get_recommendations_genre_similarity(select_artist, df, top): 
    # TfidfVectorizer를 사용하여 장르를 벡터화합니다.
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(df['genres'])

    artist_list = []
    select_artist = [artist.strip().lower() for artist in select_artist]
    
    for artist in select_artist:
        artist_df = df[df['artist'] == artist]
        
        if artist_df.empty:
            print(f"Artist {artist} not found in the DataFrame.")
            continue  # Skip if artist is not found
        
        artist_indices = artist_df.index.tolist()        
        artist_tfidf = tfidf_matrix[artist_indices].mean(axis=0)
        artist_tfidf = np.asarray(artist_tfidf).flatten()
        genre_sim = cosine_similarity([artist_tfidf], tfidf_matrix).flatten()
        similar_indices = np.argsort(-genre_sim)[1:top+1]
        temp = df.iloc[similar_indices]
        
        #선택한 아티스트 장르 == 요건 어떻게 할지 고민중
        # temp = temp[~temp['artist'].isin(select_artist)]
        
        # temp가 비어 있지 않을 때만 genre_similarity 추가
        if not temp.empty:
            temp['genre_similarity'] = genre_sim[similar_indices][:len(temp)]
            artist_list.append(temp)
        
    # 결과 데이터프레임으로 반환
    if artist_list:
        result_df = pd.concat(artist_list, ignore_index=True)
        return result_df
    else:
        return pd.DataFrame()


def get_recommendations_playlist_track_id(track_audio_features_list, df, count = 5):
   
    audio_features_columns = ['acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'valence'] 

    if len(track_audio_features_list) <= 0:
                return pd.DataFrame()

    rec = []
    for _, track_row in track_audio_features_list.iterrows():
        playlist_vector = track_row[audio_features_columns].values.reshape(1, -1)
        track_features = df[audio_features_columns].values

        # 코사인 유사도 계산
        similarity_scores = cosine_similarity(playlist_vector, track_features).flatten()

        # 자기 자신 제외한 상위 추천 트랙 인덱스
        sorted_indices = np.argsort(similarity_scores)[::-1]  # 내림차순 정렬
        similar_indices = sorted_indices[sorted_indices != _][:count]  # 자기 자신 제외, 상위 count 선택

        # 유효한 인덱스만 필터링
        valid_indices = [idx for idx in similar_indices if idx < len(df)]
        if not valid_indices:
            continue

        # 추천 트랙 추출
        similar_tracks = df.iloc[valid_indices].copy()
        similar_tracks['cosine_similarity_score'] = similarity_scores[valid_indices]
        rec.append(similar_tracks)

    return rec

def get_recommendations(df:pd.DataFrame, sp:SpotifyOAuth, select_artist = ['lady gaga', 'jimin']):
    user_playlists = get_user_playlists(sp)
    print(len(user_playlists))

    # 장르 기반
    if len(user_playlists) <= 0:
        result1 =  get_recommendations_genre_similarity(select_artist, df, 10) 
        display(result1)
    # 플레이리스트 음악적 특성 유사도
    else:
        result = []           
        for playlist_id in user_playlists:
            tracks = sp.playlist_tracks(playlist_id)

            track_id_list = []
            for track_item in tracks['items']:
                track = track_item['track']
                if df['track_id'].isin([track['id']]).any():  # track_id가 df에 존재하는지 확인
                    track_id_list.append(track['id'])
   
            track_audio_features_list = df[df['track_id'].isin(track_id_list)]
            result.append(get_recommendations_playlist_track_id(track_audio_features_list, df, 5))
        
        display(result)

load_file_path = 'C:\\Users\\user\\Documents\\dev\\upstageailab-ml-pjt-ml_p5\\mlflow\\df_ml5_genre_no_delete.csv'
df = pd.read_csv(load_file_path, sep=',')

df['artist'] = df['artist'].apply(lambda x: ''.join(e for e in x if e.isalnum() or e.isspace()))
df['artist'] = df['artist'].str.strip().str.lower()  # 소문자로 변환

df['genres'] = df['genres'].apply(lambda x: ''.join(e for e in x if e.isalnum() or e.isspace()))
df['genres'] = df['genres'].str.strip().str.lower()  # 소문자로 변환

get_recommendations(df, sp)
# Out:
# 1
# [[      Unnamed: 0                track_id                   track_name  \
#   6511        6511  17tDv8WA8IhqE8qzuQn707  My First Kiss - feat. Ke$ha
#   5010        5010  381g0b6QZxC13SzA2HRMIc                     Power Up
#   43            43  3w3y8KPTfNeOKPiqUTakBh         Locked out of Heaven
#   2487        2487  6gbLpUQtUU8ojzbE9jKt5A                  On Somebody
#   3453        3453  5vTPxzm4h2bY9rYyVrGEU5            Really Don't Care
#
#         track_popularity track_album_release_date  danceability  energy  key  \
#   6511                61               2010-06-25         0.682   0.889    0
#   5010                65               2018-08-06         0.732   0.934    8
#   43                  89               2012-12-07         0.726   0.698    5
#   2487                72               2019-12-30         0.698   0.742    5
#   3453                69               2013-01-01         0.706   0.728    7
#
#         loudness  mode  ...  valence    tempo  duration_ms  \
#   6511    -4.166     1  ...    0.827  138.021       192440
#   5010    -4.618     1  ...    0.898  159.998       202040
#   43      -4.165     1  ...    0.867  143.994       233478
#   2487    -4.169     0  ...    0.767  137.844       184565
#   3453    -3.602     1  ...    0.851  121.017       201600
#
#                       album_id                        album_name  \
#   6511  1W9toxqtPfieKk6cft0f7R                   Streets Of Gold
#   5010  5zWa1ZEUBctbKqvwXbFawo  Summer Magic - Summer Mini Album
#   43    58ufpQsJ1DS5kq4hhzQDiI                Unorthodox Jukebox
#   2487  6eKZQ8kCoMonJTloDdN6Gm                       On Somebody
#   3453  6Kssm2LosQ0WyLukFZkEG5                              Demi
#
#                                               album_image  \
#   6511  https://i.scdn.co/image/ab67616d0000b273bc805c...
#   5010  https://i.scdn.co/image/ab67616d0000b2736017bc...
#   43    https://i.scdn.co/image/ab67616d0000b273926f43...
#   2487  https://i.scdn.co/image/ab67616d0000b2731bcbd8...
#   3453  https://i.scdn.co/image/ab67616d0000b273aadb13...
#
#                 main_artist_id                  artist  \
#   6511  0FWzNDaEu9jdgcYTbcOa4F              3oh3 kesha
#   5010  1z4g3DjTBBZKhvAroFlhOM              red velvet
#   43    0du5cEVh5yTK9QJze8zA0C              bruno mars
#   2487  4npEfmQ6YuiwW1GpUmaq3F                 ava max
#   3453  6S2OmqARrzebs0tKUEyXyp  demi lovato cher lloyd
#
#                                                    genres  \
#   6511  dance pop electropowerpop pop punk pop rap pos...
#   5010                               kpop kpop girl group
#   43                                        dance pop pop
#   2487                                                pop
#   3453                                   pop postteen pop
#
#        cosine_similarity_score
#   6511                0.999998
#   5010                0.999998
#   43                  0.999998
#   2487                0.999998
#   3453                0.999998
#
#   [5 rows x 24 columns],
#         Unnamed: 0                track_id  \
#   2414        2414  10M2Ex445zw585Ducldzkw
#   4278        4278  1xKQbqQtQWrtQS47fUJBtl
#   2580        2580  4rkUEE5iTzG0szS8k8QzqR
#   4648        4648  7l56nY7NMP1QDdWvRdJmmg
#   3515        3515  3Nf8oGn1okobzjDcFCvT6n
#
#                                             track_name  track_popularity  \
#   2414                         In Case You Didn't Know                73
#   4278                               Piece of My Heart                67
#   2580  Flashlight - From "Pitch Perfect 2" Soundtrack                72
#   4648           Vivere Tutte Le Vite - con Carl Brave                66
#   3515                               I'll Stand by You                69
#
#        track_album_release_date  danceability  energy  key  loudness  mode  ...  \
#   2414               2017-02-10         0.607   0.536   10    -7.306     1  ...
#   4278               1968-08-12         0.443   0.727    4    -7.951     1  ...
#   2580               2015-04-14         0.383   0.616    5    -7.118     1  ...
#   4648               2019-05-03         0.604   0.639   11    -8.501     0  ...
#   3515               1994-06-01         0.438   0.606    7    -6.549     1  ...
#
#         valence    tempo  duration_ms                album_id  \
#   2414    0.434  147.986       224853  6MTPPsqX8KnmDWmnQmbxJ5
#   4278    0.566  160.820       253333  2rogKfOpmCFuqNhtGKf2dX
#   2580    0.480  147.625       208667  7JsgaEeIsP8gpRxmA30ErD
#   4648    0.491  171.887       220604  4MmmI8sqP83TZzmg0AyTae
#   3515    0.266  133.822       240760  6MH35oajuCbpS9YBmwTrPf
#
#                                             album_name  \
#   2414                                     Brett Young
#   4278                                   Cheap Thrills
#   2580  Flashlight (From "Pitch Perfect 2" Soundtrack)
#   4648                                    Diari Aperti
#   3515                        Last of the Independents
#
#                                               album_image  \
#   2414  https://i.scdn.co/image/ab67616d0000b2738c6751...
#   4278  https://i.scdn.co/image/ab67616d0000b2731ba5ee...
#   2580  https://i.scdn.co/image/ab67616d0000b273b5cd57...
#   4648  https://i.scdn.co/image/ab67616d0000b273fff9bc...
#   3515  https://i.scdn.co/image/ab67616d0000b273b2bcbf...
#
#                 main_artist_id                                         artist  \
#   2414  0fiWOxhsBsQQvFDtxUQWo0                                    brett young
#   4278  4J69yWrKwWJgjv3DKTZcGo  big brother  the holding company janis joplin
#   2580  2gsggkzM5R49q6jpPvazou                                       jessie j
#   4648  2ARH58Hit3yC6ziGdhma23                               elisa carl brave
#   3515  0GByy3DcfbQwDvXGCWmzv9                                     pretenders
#
#                                                    genres  \
#   2414          contemporary country country country road
#   4278              blues rock folk rock psychedelic rock
#   2580                                      dance pop pop
#   4648                      italian adult pop italian pop
#   3515  album rock classic rock mellow gold new romant...
#
#        cosine_similarity_score
#   2414                0.999999
#   4278                0.999999
#   2580                0.999999
#   4648                0.999999
#   3515                0.999999
#
#   [5 rows x 24 columns],
#         Unnamed: 0                track_id                     track_name  \
#   5949        5949  34i4yxPrHWquuR4kjiivFO                  Somebody Else
#   3342        3342  2p4p9YGwmJIdf5IA9sSWhm                           STFU
#   8299        8299  7IlYDWKUtjuQ1xPf6KAzWc  Shopping (feat. Kesi & Stepz)
#   4380        4380  2X9fsxb6O6bYEopJYmUbNC                           Gold
#   6148        6148  6uYAPqxP69zfpCbsTHXgiz                      Cater 2 U
#
#         track_popularity track_album_release_date  danceability  energy  key  \
#   5949                62               2016-09-09         0.674   0.593   11
#   3342                69               2017-03-24         0.822   0.471    1
#   8299                57               2020-01-01         0.809   0.632   11
#   4380                66               2000-05-15         0.711   0.740   10
#   6148                62               2004-11-16         0.605   0.584   11
#
#         loudness  mode  ...  valence    tempo  duration_ms  \
#   5949    -6.470     0  ...    0.464  116.995       233077
#   3342    -7.303     0  ...    0.512  135.070       230878
#   8299    -7.626     0  ...    0.519  140.036       214247
#   4380    -7.776     0  ...    0.638  143.047       231480
#   6148    -7.043     0  ...    0.464  125.802       245400
#
#                       album_id                         album_name  \
#   5949  3Q4yhhyFA2cpZq2FGOgMwU                      Somebody Else
#   3342  5WS1g0cKtjfK6eDoSLdv7d                           Mansionz
#   8299  1AbbAD01UOkL5KQINxEfv4                               1010
#   4380  5UUutTu9xlQnG9duYrIIW7  Gold - The Best of Spandau Ballet
#   6148  0b6ivSFfDs38MG7aLn9rvO                  Destiny Fulfilled
#
#                                               album_image  \
#   5949  https://i.scdn.co/image/ab67616d0000b273ce94af...
#   3342  https://i.scdn.co/image/ab67616d0000b27390d0e1...
#   8299  https://i.scdn.co/image/ab67616d0000b2734fcfb3...
#   4380  https://i.scdn.co/image/ab67616d0000b27357051c...
#   6148  https://i.scdn.co/image/ab67616d0000b2735a4df8...
#
#                 main_artist_id                      artist  \
#   5949  1Fr6agZ6iSM5Ynn2k4C8sc                      vérité
#   3342  2o8lOQRjzsSC8UdbNN88HN  mansionz spark master tape
#   8299  2eBqkaIfoNsOPCQCQEy5fD       benny jamz kesi stepz
#   4380  2urZrEdsq72kx0UzfYN8Yv              spandau ballet
#   6148  1Y8cdNmUJH7yBTd9yOvr5i              destinys child
#
#                                                    genres  \
#   5949  alt z brooklyn indie dark pop electropop indie...
#   3342                                      indie pop rap
#   8299                          danish hip hop danish pop
#   4380  new romantic new wave new wave pop sophistipop...
#   6148     dance pop girl group pop rb urban contemporary
#
#        cosine_similarity_score
#   5949                0.999999
#   3342                0.999999
#   8299                0.999999
#   4380                0.999999
#   6148                0.999999
#
#   [5 rows x 24 columns],
#         Unnamed: 0                track_id  \
#   95            95  4kGlAkGC58crFvxfegBhNs
#   765          765  2rc7BkzO8qepMFAxHtOrXc
#   3952        3952  7bBIBrSmHvdMlTC7b9p8Vq
#   3468        3468  2J9TGb5CRT4omfAgnKmXn5
#   3415        3415  1NHlyKgtR4roNylOhidKSv
#
#                                           track_name  track_popularity  \
#   95                                     squabble up                34
#   765                                         Blanco                88
#   3952                                         Playa                67
#   3468                                    Ostia Lido                69
#   3415  Girls Have Fun (feat. G-Eazy & Rich The Kid)                69
#
#        track_album_release_date  danceability  energy  key  loudness  mode  ...  \
#   95                 2024-11-21         0.878   0.683    0    -5.562     1  ...
#   765                2019-11-15         0.870   0.706    9    -5.395     0  ...
#   3952               2019-05-31         0.837   0.577    2    -5.854     1  ...
#   3468               2019-05-17         0.874   0.786    9    -5.723     1  ...
#   3415               2019-01-23         0.888   0.740    8    -5.363     1  ...
#
#         valence    tempo  duration_ms                album_id  \
#   95      0.721  103.951       157992  1Ss0ArMRr91m83mOgRBjSZ
#   765     0.593  100.013       145800  5mcUbpuVL0i5q4cECQ6cV4
#   3952    0.730  109.904       192000  42ekyGiDfZ3jxCywA8mLyu
#   3468    0.688  108.944       172945  0Tph6OXMMLC4oVAAi0h4Py
#   3415    0.664  100.003       175711  1KLUE6sVMdRUxD3MRUyS0M
#
#                                           album_name  \
#   95                                             GNX
#   765                                         Blanco
#   3952                                         Playa
#   3468                                    Ostia Lido
#   3415  Girls Have Fun (feat. G-Eazy & Rich The Kid)
#
#                                               album_image  \
#   95    https://i.scdn.co/image/ab67616d0000b27309d6ed...
#   765   https://i.scdn.co/image/ab67616d0000b273fc1c3e...
#   3952  https://i.scdn.co/image/ab67616d0000b273f77668...
#   3468  https://i.scdn.co/image/ab67616d0000b273c18357...
#   3415  https://i.scdn.co/image/ab67616d0000b2736a03e5...
#
#                 main_artist_id                   artist  \
#   95    2YZyLoL8N0Wb9xBt1NhZWg           kendrick lamar
#   765   1vyhD5VmyZ7KMfW5gqLgo5                 j balvin
#   3952  725KKhVCSCQbYkZBptBTfg                   baby k
#   3468  2iK8weavvfS2xJCmzNzNE5                      jax
#   3415  5LHRHt1k9lMyONurDHEdrp  tyga geazy rich the kid
#
#                                                    genres  \
#   95         conscious hip hop hip hop rap west coast rap
#   765   reggaeton reggaeton colombiano trap latino urb...
#   3952                      italian adult pop italian pop
#   3468                      italian adult pop italian pop
#   3415          hip hop pop rap rap southern hip hop trap
#
#        cosine_similarity_score
#   95                  1.000000
#   765                 0.999999
#   3952                0.999999
#   3468                0.999999
#   3415                0.999998
#
#   [5 rows x 24 columns],
#         Unnamed: 0                track_id  \
#   7902        7902  4SyadrABZJIjeND1HPJS31
#   8473        8473  61VlApj8p2ZaP0WTunTrKT
#   8384        8384  3UYuDTslR35thjQzaVwRMe
#   7875        7875  0EM0yABJzbFOvZQkfvuvCy
#   4286        4286  0G1HcY6dlx8yjJBMCO9rOc
#
#                                             track_name  track_popularity  \
#   7902                           Rollout (My Business)                58
#   8473  Give Up the Goods (Just Step) (feat. Big Noyd)                56
#   8384                                        Get Down                57
#   7875                                        TOGETHER                58
#   4286                                      Want Beef?                67
#
#        track_album_release_date  danceability  energy  key  loudness  mode  ...  \
#   7902               2001-01-01         0.921   0.668    7    -8.730     1  ...
#   8473               1995-04-25         0.782   0.597    1    -6.399     1  ...
#   8384               2002-12-13         0.835   0.718    1    -6.405     1  ...
#   7875               2016-05-06         0.825   0.694    1    -7.604     1  ...
#   4286               2019-04-20         0.867   0.492    2    -8.088     1  ...
#
#         valence    tempo  duration_ms                album_id    album_name  \
#   7902    0.892  131.059       296587  1GMj0Rx5Q6EyBYbi9Eu7Vr  Word Of Mouf
#   8473    0.528   94.631       243133  1cCAb1vN8uUsdfEylVmTLs  The Infamous
#   8384    0.507   94.387       244253  3rV1aPkrWyMs6YTvTpSbIY     God's Son
#   7875    0.809  112.017       197240  1dZZh7PvVgce1DDsDPzy8Z         99.9%
#   4286    0.567  120.981       155482  483wwfmjfxABBHDiF10Uag    Want Beef?
#
#                                               album_image  \
#   7902  https://i.scdn.co/image/ab67616d0000b27345b635...
#   8473  https://i.scdn.co/image/ab67616d0000b273a2203f...
#   8384  https://i.scdn.co/image/ab67616d0000b2730b3331...
#   7875  https://i.scdn.co/image/ab67616d0000b27342c18f...
#   4286  https://i.scdn.co/image/ab67616d0000b27314bf32...
#
#                 main_artist_id                           artist  \
#   7902  3ipn9JLAPI5GUEo4y4jcoi                         ludacris
#   8473  6O2zJ0tId7g07yzHtX0yap               mobb deep big noyd
#   8384  20qISvAhX20dpIbOOzGK3q                              nas
#   7875  6qgnBH6iDM91ipVXv28OMu  kaytranada alunageorge goldlink
#   4286  1je11NKORfLMSjgSNP0DPF             ysn flow baebae savo
#
#                                                    genres  \
#   7902  atl hip hop dance pop dirty south rap hip hop ...
#   8473  east coast hip hop hardcore hip hop hip hop qu...
#   8384  conscious hip hop east coast hip hop gangster ...
#   7875  alternative rb escape room indie soul lgbtq hi...
#   4286                                        melodic rap
#
#        cosine_similarity_score
#   7902                0.999998
#   8473                0.999997
#   8384                0.999995
#   7875                0.999995
#   4286                0.999995
#
#   [5 rows x 24 columns],
#         Unnamed: 0                track_id                 track_name  \
#   8254        8254  1WoChv2ARhrKUhzHcmWqLd         If I Ain't Got You
#   2531        2531  6mYrhCAGWzTdF8QnKuchXM  If I Could Turn Back Time
#   5940        5940  2RZG69vGcBkMGZQf7JiO3v          You Are Losing Me
#   8748        8748  5xLfQuX5YAfog2JgPz0dpA           Moving in Stereo
#   2782        2782  4osgfFTICMkcGbbigdsa53                   Novacane
#
#         track_popularity track_album_release_date  danceability  energy  key  \
#   8254                57               2019-03-22         0.626   0.475    8
#   2531                72               1989-01-01         0.658   0.575   11
#   5940                62               2019-09-27         0.577   0.430    7
#   8748                56               1978-06-06         0.718   0.543    4
#   2782                71               2011-01-01         0.762   0.508    3
#
#         loudness  mode  ...  valence    tempo  duration_ms  \
#   8254    -8.086     1  ...    0.424   84.035       177851
#   2531   -10.365     1  ...    0.504  108.329       239827
#   5940    -9.764     1  ...    0.346   99.982       207333
#   8748   -11.238     1  ...    0.370  115.522       286107
#   2782    -9.112     1  ...    0.370   93.510       302347
#
#                       album_id          album_name  \
#   8254  5kzHHrO8DMBOkHpcmKQ5BP  If I Ain't Got You
#   2531  3srdrIrP3V7LTmRujRfLhK      Heart Of Stone
#   5940  6oZI1hY0Xm2CYBA2Wvs2GA   You Are Losing Me
#   8748  4tJPWT4r4FSKwy784Qs1Fq            The Cars
#   2782  3RYdEXhGHojkTILUdtnRVJ            Novacane
#
#                                               album_image  \
#   8254  https://i.scdn.co/image/ab67616d0000b273e167ef...
#   2531  https://i.scdn.co/image/ab67616d0000b2737a1e02...
#   5940  https://i.scdn.co/image/ab67616d0000b273591b60...
#   8748  https://i.scdn.co/image/ab67616d0000b273f725bc...
#   2782  https://i.scdn.co/image/ab67616d0000b27359a428...
#
#                 main_artist_id          artist  \
#   8254  0Vu4A064M7J86SoMA0nrJH    dan talevski
#   2531  72OaDtakiy6yFqkt4TsiFt            cher
#   5940  5JMLG56F1X5mFmWNmS0iAp  chelsea cutler
#   8748  6DCIj8jNaNpBz8e5oKFPtp        the cars
#   2782  2h93pZq0e7k5yf4dywlkpM     frank ocean
#
#                                                    genres  \
#   8254                                       canadian pop
#   2531                                      dance pop pop
#   5940                                              alt z
#   8748  album rock classic rock hard rock mellow gold ...
#   2782                             lgbtq hip hop neo soul
#
#        cosine_similarity_score
#   8254                0.999999
#   2531                0.999998
#   5940                0.999998
#   8748                0.999998
#   2782                0.999998
#
#   [5 rows x 24 columns],
#         Unnamed: 0                track_id                        track_name  \
#   1605        1605  6jreFSOTUAViWjKyzOC4Kg                            REMEDY
#   2139        2139  4Eefey3uN90Abhbr47zKmC            WINTER FLOWER(Feat.RM)
#   1975        1975  1wsLHgXJ4SKIfd5ePSX1hD                          Polaroid
#   3101        3101  1vsQb8n0icvMsFnL9663LM  Need Your Love (with Noah Kahan)
#   9426        9426  7dLOOzJGQnsgqFcflWiEcZ                          Only You
#
#         track_popularity track_album_release_date  danceability  energy  key  \
#   1605                77               2018-08-31         0.601   0.775    0
#   2139                74               2020-01-06         0.575   0.793    0
#   1975                75               2018-10-05         0.652   0.897    7
#   3101                70               2019-10-24         0.581   0.760    0
#   9426                54               2019-11-15         0.565   0.732    8
#
#         loudness  mode  ...  valence    tempo  duration_ms  \
#   1605    -4.612     1  ...    0.483  119.964       190295
#   2139    -3.669     1  ...    0.262   95.845       221133
#   1975    -4.481     0  ...    0.475  114.033       193377
#   3101    -3.962     1  ...    0.523  104.099       205787
#   9426    -4.354     1  ...    0.265  114.901       182609
#
#                       album_id        album_name  \
#   1605  0LOJHhz9ybWLVMLucHYtCe            REMEDY
#   2139  7tY3mqjeJaMr6RFJYnjI2s  UNSTABLE MINDSET
#   1975  10bTwLR8vJxwE2SeHZxkrS          Polaroid
#   3101  5CaTHgZaRvb2vCK1mVbCR1           Gravity
#   9426  2IgoG92BBQMm6mB6ZjiQX9          Only You
#
#                                               album_image  \
#   1605  https://i.scdn.co/image/ab67616d0000b273a74798...
#   2139  https://i.scdn.co/image/ab67616d0000b2734b89d5...
#   1975  https://i.scdn.co/image/ab67616d0000b273db69f9...
#   3101  https://i.scdn.co/image/ab67616d0000b2733f8642...
#   9426  https://i.scdn.co/image/ab67616d0000b27310ed33...
#
#                 main_artist_id                               artist  \
#   1605  4AVFqumd2ogHFlRbKIjp1t                               alesso
#   2139  6GwM5CHqhWXzG3l5kzRSAS                            younha rm
#   1975  1HBjj22wzbscIZ9sEb5dyf  jonas blue liam payne lennon stella
#   3101  2ZRQcIgzPCVaT9XKhXZIzh       gryffin seven lions noah kahan
#   9426  5s21IKPvmxRf9WxpO8H5UB                 hogland bryan finlay
#
#                                                    genres  \
#   1605  dance pop edm pop pop dance progressive electr...
#   2139                                         korean pop
#   1975              pop pop dance tropical house uk dance
#   3101                                      edm pop dance
#   9426                deep pop edm swedish tropical house
#
#        cosine_similarity_score
#   1605                0.999999
#   2139                0.999999
#   1975                0.999999
#   3101                0.999998
#   9426                0.999998
#
#   [5 rows x 24 columns],
#         Unnamed: 0                track_id  \
#   6881        6881  2NRUU0gP1d8Yif8CpsCW8l
#   6878        6878  4m63ZA9od3vICn0AOEG5qo
#   2153        2153  4KilYheWwxakB1L43ECTeP
#   6214        6214  5l8oNQsDDPNFUIV5M4lzRJ
#   4609        4609  6GefwzSnQkQoCnWJNs9IZR
#
#                                        track_name  track_popularity  \
#   6881                                      Faded                60
#   6878                 Sheep (Alan Walker Relift)                60
#   2153  Gigolò (feat. Sfera Ebbasta & Capo Plaza)                74
#   6214                                Free Animal                61
#   4609                                  RENT FREE                66
#
#        track_album_release_date  danceability  energy  key  loudness  mode  ...  \
#   6881               2012-01-01         0.831   0.667    1    -8.438     1  ...
#   6878               2018-08-31         0.692   0.666    6    -7.998     0  ...
#   2153               2019-10-03         0.795   0.634    5    -8.771     0  ...
#   6214               2015-11-17         0.579   0.584    5    -7.151     0  ...
#   4609               2019-09-13         0.784   0.543    6    -9.769     1  ...
#
#         valence    tempo  duration_ms                album_id  \
#   6881    0.339   95.073       206667  3KHamR7LZmFT0xqPA1Hyob
#   6878    0.259   89.995       156000  573ArsbGpyQHQqry8tii2G
#   2153    0.390   97.512       164302  18oJqI5kIQ5lwDvpdlny99
#   6214    0.393   80.001       180400  7I82cxUhP77MAqBeY9hkVa
#   4609    0.451  108.982       150200  4rNgGxoqUkFBZOMEb7PKoD
#
#                                    album_name  \
#   6881  Careless World: Rise Of The Last King
#   6878             Sheep (Alan Walker Relift)
#   2153                        Re Mida (Aurum)
#   6214                            Free Animal
#   4609                              RENT FREE
#
#                                               album_image  \
#   6881  https://i.scdn.co/image/ab67616d0000b273057041...
#   6878  https://i.scdn.co/image/ab67616d0000b2737544b8...
#   2153  https://i.scdn.co/image/ab67616d0000b273113808...
#   6214  https://i.scdn.co/image/ab67616d0000b273094e8a...
#   4609  https://i.scdn.co/image/ab67616d0000b273bd1b66...
#
#                 main_artist_id                          artist  \
#   6881  5LHRHt1k9lMyONurDHEdrp                  tyga lil wayne
#   6878  7vk5e3vY1uw9plTHJAMwjN                 alan walker lay
#   2153  0jdNdfi4vAuVi7a6cPDFBM  lazza sfera ebbasta capo plaza
#   6214  5ApQnMT6oR8eLguf24xb9S                     foreign air
#   4609  1z7b1Pr1rSlvWRzsW3HOrS                            russ
#
#                                                    genres  \
#   6881          hip hop pop rap rap southern hip hop trap
#   6878                                      electro house
#   2153  italian hip hop italian pop rap genovese trap ...
#   6214  charlotte nc indie indie poptimism modern alte...
#   4609                           hawaiian hip hop pop rap
#
#        cosine_similarity_score
#   6881                0.999998
#   6878                0.999998
#   2153                0.999997
#   6214                0.999997
#   4609                0.999997
#
#   [5 rows x 24 columns],
#         Unnamed: 0                track_id          track_name  \
#   9294        9294  5cOM0fTHceCkJVwuyHdMnk  Who Can It Be Now?
#   2500        2500  0gb1J5UrTpzaU1s3nupgCd            No Money
#   4547        4547  5xzCzOAOfRi4DOttSzvznR             Lullaby
#   4775        4775  3jUTjCISntIUFL8jnAjzgc       Fallen Leaves
#   1786        1786  1pwo8l3Ko7idwaz4LVUEC4  Shout Out to My Ex
#
#         track_popularity track_album_release_date  danceability  energy  key  \
#   9294                55               1996-02-01         0.816   0.791    4
#   2500                72               2016-04-01         0.671   0.916    6
#   4547                66               2018-02-23         0.725   0.834    5
#   4775                65               2006-06-23         0.710   0.811    3
#   1786                76               2017-11-24         0.773   0.747    5
#
#         loudness  mode  ...  valence    tempo  duration_ms  \
#   9294    -4.210     1  ...    0.963  128.521       200493
#   2500    -4.014     0  ...    0.803  126.010       189127
#   4547    -3.913     0  ...    0.859  120.026       204022
#   4775    -4.079     1  ...    0.914  123.048       199200
#   1786    -4.061     1  ...    0.800  126.014       246240
#
#                       album_id                           album_name  \
#   9294  6GYIy1SuhPDrugCZ5yNeQy  The Best Of Men At Work: Contraband
#   2500  2f7kOrpFos0njurSOi2zqL                             No Money
#   4547  1SR7c6j94aiuYEhUrfTbZ7                              Lullaby
#   4775  0cTOvcvrbNiaiv4WXEUHzT                      Billy Talent II
#   1786  5DL2Z5x7UJsWH1HhE9j8nd     Glory Days: The Platinum Edition
#
#                                               album_image  \
#   9294  https://i.scdn.co/image/ab67616d0000b273d6a1f7...
#   2500  https://i.scdn.co/image/ab67616d0000b273119cb5...
#   4547  https://i.scdn.co/image/ab67616d0000b273e93308...
#   4775  https://i.scdn.co/image/ab67616d0000b27351ad16...
#   1786  https://i.scdn.co/image/ab67616d0000b273c11062...
#
#                 main_artist_id               artist  \
#   9294  0f3EsoviYnRKTkmayI3cux          men at work
#   2500  4sTQVOfp9vEMCemLw50sbu             galantis
#   4547  1IueXOQyABrMOprrzwQJWN  sigala paloma faith
#   4775  08yf5A2nS4XEeNvabDXqyg         billy talent
#   1786  3e7awlrlDSwF3iM0WBjGMp           little mix
#
#                                                    genres  \
#   9294  album rock australian rock classic rock hard r...
#   2500  dance pop edm pop pop dance progressive electr...
#   4547                   dance pop edm pop dance uk dance
#   4775                                      canadian punk
#   1786                  girl group pop talent show uk pop
#
#        cosine_similarity_score
#   9294                0.999999
#   2500                0.999999
#   4547                0.999999
#   4775                0.999999
#   1786                0.999999
#
#   [5 rows x 24 columns],
#         Unnamed: 0                track_id             track_name  \
#   3090        3090  1xPpYbCaJWonL7IFXPDjON  Taste (Make It Shake)
#   9372        9372  4LaiF2h7gsybmURceGYLqh       Clan In Da Front
#   7404        7404  5oqSr3rehtGgZyDh0LCSA7         Gotta Get Mine
#   9243        9243  3HCzj965m8Fz2E8wZkir6q          They Want EFX
#   9879        9879  4Uxb6ZyCz6YnB0Rr85IsS8               Backwood
#
#         track_popularity track_album_release_date  danceability  energy  key  \
#   3090                70               2019-09-06         0.761   0.442    0
#   9372                54               1993-11-09         0.707   0.617    6
#   7404                59               1993-01-01         0.855   0.520    7
#   9243                55               1992-04-07         0.755   0.459    5
#   9879                53               2016-10-21         0.610   0.382    5
#
#         loudness  mode  ...  valence   tempo  duration_ms  \
#   3090   -12.872     1  ...    0.706  97.753       213680
#   9372   -12.519     1  ...    0.594  96.051       273320
#   7404   -12.070     1  ...    0.402  92.451       264760
#   9243   -12.840     0  ...    0.597  98.454       221400
#   9879    -9.591     0  ...    0.590  74.084       168213
#
#                       album_id  \
#   3090  4lyOYAUAPXImW4OCQT2wiP
#   9372  3tQd5mwBtVyxCoEo4htGAV
#   7404  63fBdGVcKoOOcI1eLOoDwT
#   9243  5L6ETkYF4PeD1pSrAGKuNf
#   9879  1x6E0JYj6wKFHfZQFQCpnU
#
#                                                album_name  \
#   3090                                            AitcH2O
#   9372  Enter The Wu-Tang (36 Chambers) [Expanded Edit...
#   7404                                      The New Breed
#   9243                                       Dead Serious
#   9879                                             PHO EP
#
#                                               album_image  \
#   3090  https://i.scdn.co/image/ab67616d0000b27381225a...
#   9372  https://i.scdn.co/image/ab67616d0000b2735901aa...
#   7404  https://i.scdn.co/image/ab67616d0000b273926383...
#   9243  https://i.scdn.co/image/ab67616d0000b27348cede...
#   9879  https://i.scdn.co/image/ab67616d0000b27336eac8...
#
#                 main_artist_id       artist  \
#   3090  2PJEagPIxaBugeMjIyKVXF        aitch
#   9372  34EP7KEpOjXcM2TCat1ISk  wutang clan
#   7404  63727CmmJ8oWFh8eAHvDYq     mc breed
#   9243  0auu2itHTxEdAMRHvx7CyG      das efx
#   9879  1vaQ6v3pOFxAIrFoPrAcom   ari lennox
#
#                                                    genres  \
#   3090                      manchester hip hop uk hip hop
#   9372  east coast hip hop gangster rap hardcore hip h...
#   7404                         flint hip hop gangster rap
#   9243                east coast hip hop hardcore hip hop
#   9879                                     alternative rb
#
#        cosine_similarity_score
#   3090                0.999995
#   9372                0.999995
#   7404                0.999994
#   9243                0.999993
#   9879                0.999991
#
#   [5 rows x 24 columns]]]
